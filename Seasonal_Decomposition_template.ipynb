# %% [markdown]
# <a href="https://colab.research.google.com/github/psy-pri/forecasting_models/blob/main/Seasonal_Decomposition_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Forecasting+Models+and+Time+Series+for+Business+in+Python-20220613T155755Z-001/Forecasting Models and Time Series for Business in Python
# Out:
# /content/drive/MyDrive/Forecasting+Models+and+Time+Series+for+Business+in+Python-20220613T155755Z-001/Forecasting Models and Time Series for Business in Python

# %%
#import libraries

import pandas as pd
import numpy as np

# %%
#get the data
data = pd.read_csv("Daily Bike Sharing.csv",
                   index_col = "dteday",
                   parse_dates = True)
data.head(1)
# Out:
#             instant  season  yr  mnth  holiday  weekday  workingday  \
# dteday
# 2011-01-01        1       1   0     1        0        6           0
#
#             weathersit      temp     atemp       hum  windspeed  casual  \
# dteday
# 2011-01-01           2  0.344167  0.363625  0.805833   0.160446     331
#
#             registered  cnt
# dteday
# 2011-01-01         654  985

# %%
#select variables
dataset = data.loc[:,["cnt", "holiday", "workingday", "weathersit",
                      "temp", "atemp", "hum", "windspeed"]]
dataset.head(1)
# Out:
#             cnt  holiday  workingday  weathersit      temp     atemp  \
# dteday
# 2011-01-01  985        0           0           2  0.344167  0.363625
#
#                  hum  windspeed
# dteday
# 2011-01-01  0.805833   0.160446

# %% [markdown]
# # Data Transformation

# %%
#renaming variable
dataset = dataset.rename(columns = {"cnt":"y"})
dataset.head(1)
# Out:
#               y  holiday  workingday  weathersit      temp     atemp  \
# dteday
# 2011-01-01  985        0           0           2  0.344167  0.363625
#
#                  hum  windspeed
# dteday
# 2011-01-01  0.805833   0.160446

# %%
#index (python doesnt understand freq explicitly)
dataset = dataset.asfreq("D")
dataset.index
# Out:
# DatetimeIndex(['2011-01-01', '2011-01-02', '2011-01-03', '2011-01-04',
#                '2011-01-05', '2011-01-06', '2011-01-07', '2011-01-08',
#                '2011-01-09', '2011-01-10',
#                ...
#                '2012-12-22', '2012-12-23', '2012-12-24', '2012-12-25',
#                '2012-12-26', '2012-12-27', '2012-12-28', '2012-12-29',
#                '2012-12-30', '2012-12-31'],
#               dtype='datetime64[ns]', name='dteday', length=731, freq='D')

# %% [markdown]
# # Visualization

# %%
#viz
dataset["y"].plot(figsize = (10,7), legend = True)
# Out:
# <Axes: xlabel='dteday'>

# %% [markdown]
# # Seasonal Decomposition

# %%
#library
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
#decomposition
decomposition  = seasonal_decompose(x = dataset.y,
                                    model = 'multiplicative',
                                    period = 365)
decomposition.plot();

# %%
#seasonality graphs
from statsmodels.graphics.tsaplots import month_plot, quarter_plot
month_plot(dataset.y.resample(rule = 'MS').mean());
quarter_plot(dataset.y.resample(rule = 'Q').mean());
